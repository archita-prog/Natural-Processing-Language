# %%
import spacy

# %%
nlp = spacy.blank("en")
doc = nlp("Joe Green ate 100$ of food. Then he said I can do this all day.")

for token in doc:
    print(token)
# Out:
# Joe
# Green
# ate
# 100
# $
# of
# food
# .
# Then
# he
# said
# I
# can
# do
# this
# all
# day
# .

# %%
nlp.pipe_names
# Out:
# []

# %%
nlp= spacy.load("en_core_web_sm")

# %%
nlp.pipe_names
# Out:
# ['tok2vec', 'tagger', 'parser', 'attribute_ruler', 'lemmatizer', 'ner']

# %%
nlp.pipeline
# Out:
# [('tok2vec', <spacy.pipeline.tok2vec.Tok2Vec at 0x29024048820>),
#  ('tagger', <spacy.pipeline.tagger.Tagger at 0x290240ad900>),
#  ('parser', <spacy.pipeline.dep_parser.DependencyParser at 0x29026e13df0>),
#  ('attribute_ruler',
#   <spacy.pipeline.attributeruler.AttributeRuler at 0x29026e94240>),
#  ('lemmatizer', <spacy.lang.en.lemmatizer.EnglishLemmatizer at 0x290271ce7c0>),
#  ('ner', <spacy.pipeline.ner.EntityRecognizer at 0x290271e4040>)]

# %%
doc = nlp("Joe Green ate 100$ of food. Then he said I can do this all day.")

for token in doc:
    print(token, " | ", token.pos, " | ", token.lemma_)
# Out:
# Joe  |  univ_pos_t.PROPN  |  Joe
# Green  |  univ_pos_t.PROPN  |  Green
# ate  |  univ_pos_t.VERB  |  eat
# 100  |  univ_pos_t.NUM  |  100
# $  |  univ_pos_t.NUM  |  $
# of  |  univ_pos_t.ADP  |  of
# food  |  univ_pos_t.NOUN  |  food
# .  |  univ_pos_t.PUNCT  |  .
# Then  |  univ_pos_t.ADV  |  then
# he  |  univ_pos_t.PRON  |  he
# said  |  univ_pos_t.VERB  |  say
# I  |  univ_pos_t.PRON  |  I
# can  |  univ_pos_t.AUX  |  can
# do  |  univ_pos_t.VERB  |  do
# this  |  univ_pos_t.PRON  |  this
# all  |  univ_pos_t.DET  |  all
# day  |  univ_pos_t.NOUN  |  day
# .  |  univ_pos_t.PUNCT  |  .

# %%
doc = nlp("Tesla Inc is going to acquire twitter for $45 billion")
for ent in doc.ents:
    print(ent.text, " | ", ent.label_, " | ", spacy.explain(ent.label_))
# Out:
# Tesla Inc  |  ORG  |  Companies, agencies, institutions, etc.
# $45 billion  |  MONEY  |  Monetary values, including unit

# %%
from spacy import displacy
displacy.render(doc, style = "ent")
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tesla Inc
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  is going to acquire twitter for
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     $45 billion
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# </div></span>

# %%
import spacy.cli
spacy.cli.download("fr_core_news_sm")
# Out:
# ✔ Download and installation successful
# You can now load the package via spacy.load('fr_core_news_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
nlp = spacy.load("fr_core_news_sm")
oc = nlp("Tesla Inc va racheter Twitter pour $45 milliards de dollars")
for ent in doc.ents:
    print(ent.text, " | ", ent.label_, " | ", spacy.explain(ent.label_))
# Out:
# Tesla Inc  |  ORG  |  Companies, agencies, institutions, etc.
# $45 billion  |  MONEY  |  Monetary values, including unit

# %%
source_nlp = spacy.load("en_core_web_sm")
nlp = spacy.blank("en")
nlp.add_pipe("ner", source = source_nlp)
nlp.pipe_names
# Out:
# ['ner']

# %%
doc = nlp("Tesla Inc is going to acquire twitter for $45 billion")
for en in doc.ents:
    print(ent.text , " | ", ent.label_, " | ", spacy.explain(ent.label_))
# Out:
# $45 billion  |  MONEY  |  Monetary values, including unit
# $45 billion  |  MONEY  |  Monetary values, including unit
