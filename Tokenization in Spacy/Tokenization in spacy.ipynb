# %%
import spacy

# %%
nlp = spacy.blank("en")
doc = nlp("it is raining in NewYork city. I is not my favourite time of the year.")

for token in doc:
    print(token)
# Out:
# it
# is
# raining
# in
# NewYork
# city
# .
# I
# is
# not
# my
# favourite
# time
# of
# the
# year
# .

# %%
doc[-2]
# Out:
# year

# %%
type(doc)
# Out:
# spacy.tokens.doc.Doc

# %%
doc = nlp("Tony gave two $ to Peter")

# %%
token0 = doc[0]
token0
# Out:
# Tony

# %%
dir(token0)
# Out:
# ['_',
#  '__bytes__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__pyx_vtable__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__unicode__',
#  'ancestors',
#  'check_flag',
#  'children',
#  'cluster',
#  'conjuncts',
#  'dep',
#  'dep_',
#  'doc',
#  'ent_id',
#  'ent_id_',
#  'ent_iob',
#  'ent_iob_',
#  'ent_kb_id',
#  'ent_kb_id_',
#  'ent_type',
#  'ent_type_',
#  'get_extension',
#  'has_dep',
#  'has_extension',
#  'has_head',
#  'has_morph',
#  'has_vector',
#  'head',
#  'i',
#  'idx',
#  'iob_strings',
#  'is_alpha',
#  'is_ancestor',
#  'is_ascii',
#  'is_bracket',
#  'is_currency',
#  'is_digit',
#  'is_left_punct',
#  'is_lower',
#  'is_oov',
#  'is_punct',
# ...

# %%
token0.like_num
# Out:
# False

# %%
token2 = doc[2]
token2.text
# Out:
# 'two'

# %%
token3 = doc[3]
token3.text
# Out:
# '$'

# %%
token3.is_currency
# Out:
# True

# %%
for token in doc:
    print(token, "==>", "index:", token.i,
         "is_alpha:", token.is_alpha,
         "is_punct:", token.like_num,
         "is_currency:", token.is_currency,
         )
# Out:
# Tony ==> index: 0 is_alpha: True is_punct: False is_currency: False
# gave ==> index: 1 is_alpha: True is_punct: False is_currency: False
# two ==> index: 2 is_alpha: True is_punct: True is_currency: False
# $ ==> index: 3 is_alpha: False is_punct: False is_currency: True
# to ==> index: 4 is_alpha: True is_punct: False is_currency: False
# Peter ==> index: 5 is_alpha: True is_punct: False is_currency: False

# %%
with open("students.txt") as f:
    text = f.readlines()
text
# Out:
# ['Dayton high school, 8th grade students information\n',
#  '==================================================\n',
#  '\n',
#  'Name\tbirth day   \temail\n',
#  '-----\t------------\t------\n',
#  'Virat   5 June, 1882    virat@kohli.com\n',
#  'Maria\t12 April, 2001  maria@sharapova.com\n',
#  'Serena  24 June, 1998   serena@williams.com \n',
#  'Joe      1 May, 1997    joe@root.com\n',
#  '\n',
#  '\n',
#  '\n']

# %%
text = ' '.join(text)
text
# Out:
# 'Dayton high school, 8th grade students information\n ==================================================\n \n Name\tbirth day   \temail\n -----\t------------\t------\n Virat   5 June, 1882    virat@kohli.com\n Maria\t12 April, 2001  maria@sharapova.com\n Serena  24 June, 1998   serena@williams.com \n Joe      1 May, 1997    joe@root.com\n \n \n \n'

# %%
dpc = nlp(text)
emails = []
for token in doc:
    if token.like_email:
        emails.append(token.text)
emails
# Out:
# []

# %%
nlp = spacy.blank("hi")
doc = nlp("Hi, my name is James.")
for token in doc:
    print(token)
# Out:
# Hi
# ,
# my
# name
# is
# James
# .

# %%
doc = nlp("gimme double cheese extra large pizza")
tokens = [token.text for token in doc]
tokens
# Out:
# ['gimme', 'double', 'cheese', 'extra', 'large', 'pizza']

# %%
from spacy.symbols import ORTH
nlp.tokenizer.add_special_case("gimme",[
    {ORTH: "gim"},
    {ORTH: "me"}
])
doc = nlp("gimme double cheese extra large pizza")
tokens = [token.text for  token in doc]
tokens
# Out:
# ['gim', 'me', 'double', 'cheese', 'extra', 'large', 'pizza']

# %%
nlp.add_pipe('sentencizer')

# %%
nlp.pipe_names
# Out:
# ['sentencizer']

# %%
doc = nlp("The market is located in central London. We plan to go there this weekend.")
for sentence in doc.sents:
    print(sentence)
# Out:
# The market is located in central London.
# We plan to go there this weekend.
